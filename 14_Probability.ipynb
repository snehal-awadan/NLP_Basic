# %% [markdown]
# # Theoritically Probability:

# %%
# for coin:

def coin_flip_probability():
    heads_probability = 1/2
    
    return heads_probability

# for dice:

def rolling_dice_probability(number):
    if number not in range(1,7):
        raise valueError('Number must be between 1 and 6')
    probability = 1/6
    
    return probability

# %%
# Exmple usage:

coin_flip_result = coin_flip_probability()
dice_roll_result = rolling_dice_probability(6)

print('Prob of header in a coint flip: ', coin_flip_result)
print('Prob of rolling a 4 on a die : ', dice_roll_result)
# Out:
# Prob of header in a coint flip:  0.5
# Prob of rolling a 4 on a die :  0.16666666666666666

# %% [markdown]
# # Experiment Probability:

# %%
import random
import pandas as pd

# %%
def simulate_coin_flips(num_flip):
    result = []
    
    for _ in range(num_flip):
        flip = random.choice(['heads', 'tails'])
        result.append(flip)
    return result

# %%
simulate_coin_flips(100)
# Out:
# ['tails',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'heads',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'tails',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'heads',
#  'tails',
#  'heads',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'tails',
#  'heads',
#  'heads',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'tails',
#  'tails',
#  'tails',
#  'tails',
#  'heads',
#  'heads',
#  'tails']

# %%
# how many heads and tails are there:

pd.Series(simulate_coin_flips(100)).value_counts()
# Out:
# tails    58
# heads    42
# Name: count, dtype: int64

# %%
def calculate_experimental_probability(result, event):
    event_count = result.count(event)
    total_flip = len(result)
    probability = event_count / total_flip
    
    return probability

# Example usage:

num_flips = 4000
simulate_results = simulate_coin_flips(num_flips)

heads_probability = calculate_experimental_probability(simulate_results, "heads")
tails_probability = calculate_experimental_probability(simulate_results, "tails")

print(f'Number of flips:  {num_flips}')
print(f'Heads prob: {heads_probability:.4f}')
print(f'Tails prob: {tails_probability:.4f}')
# Out:
# Number of flips:  4000
# Heads prob: 0.4933
# Tails prob: 0.5068

# %% [markdown]
# # Linear Growth:

# %%
import numpy as np

# define x:
x = np.arange(0, 10, 0.25)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
# define y:
y = x * 0.3548 + 15.35478
y
# Out:
# array([15.35478, 15.44348, 15.53218, 15.62088, 15.70958, 15.79828,
#        15.88698, 15.97568, 16.06438, 16.15308, 16.24178, 16.33048,
#        16.41918, 16.50788, 16.59658, 16.68528, 16.77398, 16.86268,
#        16.95138, 17.04008, 17.12878, 17.21748, 17.30618, 17.39488,
#        17.48358, 17.57228, 17.66098, 17.74968, 17.83838, 17.92708,
#        18.01578, 18.10448, 18.19318, 18.28188, 18.37058, 18.45928,
#        18.54798, 18.63668, 18.72538, 18.81408])

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
# reverse ==> make slope negative:

y = x * -0.3434 + 15.32434
plt.plot(x,y)

# %%
# correlation between x and y: (-1)

np.corrcoef(x,y)
# Out:
# array([[ 1., -1.],
#        [-1.,  1.]])

# %% [markdown]
# # Exponential / Polynomial Growth:

# %%
y = x ** 2 + 5.623
plt.plot(x,y)

# %% [markdown]
# # Logarithmic Growth:

# %%
plt.plot(x, np.log(x))
# Out:
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_83188\2742365056.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x))

# %% [markdown]
# # Logistic Growth:

# %%
x = np.arange(-5,5,0.25)

# sigmoid function:
y = 1/(1+ np.exp(-x))

plt.plot(x,y)
